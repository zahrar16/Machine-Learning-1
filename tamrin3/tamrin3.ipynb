# %%
import matplotlib.pyplot as plt
import numpy as np

#print(plt.__version__)

xpoints = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints, ypoints)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoints = np.array([1,8])
ypoints = np.array([3,10])

plt.plot(xpoints,ypoints)
plt.show()

# %%
plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
xpoints = np.array([1,2,6,8])
ypoints = np.array([3,8,1,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints)
plt.show()

# %%
ypoints = np.array([3,8,1,10])
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
plt.plot(ypoints, marker = '*')
plt.show()

# %%
plt.plot(ypoints, 'o:r')
plt.show()

# %%
plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
plt.plot(ypoints, marker = 'o', ms = 10, mec = 'r')
plt.show()

# %%
plt.plot(ypoints, marker = 'o', ms = 10, mfc = 'r')
plt.show()

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mec ='#4CAF50' ,mfc = '#4CAF50')
plt.show()

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
plt.show()

# %%
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
plt.plot(ypoints, ls = ':')
plt.show()

# %%
plt.plot(ypoints, color = 'r')
plt.show()

# %%
plt.plot(ypoints, color = '#4CAF50')
plt.show()

# %%
plt.plot(ypoints, color = 'hotpink')
plt.show()

# %%
plt.plot(ypoints, linewidth = 20)
plt.show()

# %%
y1 = np.array([3,8,1,10])
y2 = np.array([6,7,2,11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
x1 = np.array([0,1,2,3])
x2 = np.array([3,8,1,10])
y1 = np.array([0,1,2,3])
y2 = np.array([6,2,7,11])

plt.plot(x1,x2,y1,y2)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)

plt.xlabel("mehvar X")
plt.ylabel("mehvar Y")

plt.show()

# %%
plt.title("sport")
plt.xlabel("mehvar X")
plt.ylabel("mehvar Y")

plt.show()

# %%
font1 = {'family':'serif','color':'blue', 'size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("sport", fontdict= font1)
plt.xlabel("mehvar X", fontdict= font2)
plt.ylabel("mehvar Y", fontdict= font2)

plt.show()

# %%
plt.title("sport", loc = 'right')
plt.xlabel("mehvar X")
plt.ylabel("mehvar Y")

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)

plt.xlabel("mehvar X")
plt.ylabel("mehvar Y")

plt.grid()

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)

plt.xlabel("mehvar X")
plt.ylabel("mehvar Y")

plt.grid(color = 'red', linestyle = '--', linewidth = 0.3)

plt.show()

# %%
x = np.array([1,2,3,4])
y = np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("number 1")

x = np.array([1,2,3,4])
y = np.array([2,9,6,2])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("nember2")

plt.show()

# %%
x = np.array([1,3,8,10,19,15])
y = np.array([3,8,7,5,20,14])

plt.scatter(x,y)
plt.show()

# %%
x = np.array([1,3,8,10,19,15])
y = np.array([3,8,7,5,20,14])
plt.scatter(x,y, color = 'red')

x = np.array([2,6,8,15,20,10])
y = np.array([5,9,6,3,15,20])
plt.scatter(x,y, color = 'green')

plt.show()

# %%
x = np.array([1,3,8,10,19,15])
y = np.array([3,8,7,5,20,14])

plt.scatter(x, y)

plt.colorbar()
plt.show()

# %%
x= np.array(["a","b","c","d"])
y = np.array([1,2,3,4])

plt.bar(x,y)
plt.show()

# %%
x= np.array(["a","b","c","d"])
y = np.array([1,2,3,4])

plt.bar(x,y,color='red',width=0.1)
plt.show()

# %%
x= np.random.normal(170,10,300)
plt.hist(x)
plt.show()

# %%
y = np.array([35,10,18,5])
mylables = ["apples","orange","benana","dates"]

plt.pie(y,labels=mylables)
plt.show()
